# %%
import numpy as np
import cv2

# %%
def nothing(x):
    print(x)

cv2.namedWindow('image')

cv2.createTrackbar('CP', 'image', 10, 400, nothing)

switch = 'switch to gray'
cv2.createTrackbar(switch, 'image', 0, 1, nothing)

while(1):
    img = cv2.imread('C:\\Users\\80SM01YGIH\\Anish\\CV101\\messi5 - Copy.jpg')
    
    pos = cv2.getTrackbarPos('CP','image')
    
    font = cv2.FONT_HERSHEY_SIMPLEX
    cv2.putText(img, str(pos), (0, 150), font, 2, (0, 0, 255), 2)
    
    s = cv2.getTrackbarPos(switch, 'image')
    
    if s == 0:
        pass
    else:
        img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    cv2.imshow('image', img)
        
    k = cv2.waitKey(1) & 0xFF
    if k== 27:
        break
        
cv2.destroyAllWindows()
# Out:
# 12
# 13
# 15
# 18
# 20
# 23
# 25
# 28
# 30
# 32
# 35
# 37
# 41
# 42
# 43
# 44
# 46
# 47
# 51
# 54
# 57
# 61
# 64
# 69
# 73
# 79
# 83
# 88
# 93
# 98
# 102
# 105
# 108
# 110
# 113
# 114
# 116
# 120
# 124
# 131
# 137
# 143
# 147
# 150
# 153
# 155
# 158
# 162
# 163
# 165
# 166
# 167
# 168
# 169
# 171
# 172
# 175
# 178
# 181
# 183
# 186
# 188
# 190
# 195
# 197
# 201
# 203
# 206
# 207
# 209
# 211
# 212
# 213
# 214
# 215
# 216
# 217
# 219
# 221
# 226
# 228
# 229
# 232
# 233
# 235
# 236
# 242
# 245
# 248
# 250
# 251
# 253
# 254
# 255
# 256
# 257
# 259
# 269
# 274
# 282
# 290
# 297
# 305
# 310
# 330
# 337
# 343
# 347
# 353
# 356
# 358
# 360
# 361
# 363
# 364
# 365
# 366
# 367
# 368
# 367
# 364
# 358
# 351
# 342
# 330
# 317
# 288
# 255
# 227
# 139
# 122
# 107
# 98
# 87
# 85
# 84
# 83

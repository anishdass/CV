# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
img = cv2.imread('C:\\Users\\80SM01YGIH\\Anish\\CV101\\smarties.png', cv2.IMREAD_GRAYSCALE)
_, mask = cv2.threshold(img, 220, 255, cv2.THRESH_BINARY_INV)

kernal = np.ones((5, 5), np.uint8)

#basically dilation increases the white area and erosion increases the black area
dilation = cv2.dilate(mask, kernal, iterations = 2) # The kernel parameters defines the dimensions of the square, the bigger
                                                        #the parameters the bigger the area under the brackets will turn whilte
erosion = cv2.erode(mask, kernal, iterations = 1)

#Opening = Erosion + dilation
opening = cv2.morphologyEx(mask, cv2.MORPH_OPEN, kernal)


#Closing = dilation + erosion
closing = cv2.morphologyEx(mask, cv2.MORPH_CLOSE, kernal)

#Gradient = difference between dilation and erosion
gradient = cv2.morphologyEx(mask, cv2.MORPH_GRADIENT, kernal)

#Tophat = difference between original image and the opening.
tophat = cv2.morphologyEx(mask, cv2.MORPH_TOPHAT, kernal)

i = 8

titles = ['Original', 'Masked', 'Dilated', 'Eroded', 'Opened', 'Closed', 'Gradient', 'Tophat']
images = [img, mask, dilation1, erosion, opening, closing, gradient, tophat]

for i in range(i):
    plt.figure(figsize=(10, 10))
    plt.subplot(3, 3, i+1)
    plt.imshow(images[i], 'gray')
    plt.title(titles[i])
    plt.xticks([]), plt.yticks([])
plt.show()

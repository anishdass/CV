# %%
import cv2
import matplotlib.pyplot as plt

# %%
cap = cv2.VideoCapture(0)
while(True):
    ret, frame = cap.read()
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
    cv2.imshow('frame', gray)
    
    if cv2.waitKey(2) & 0xFF == ord('q'):
        break
        
cap.release()
cv2.destroyAllWindows()

# %%
fig, ax = plt.subplots(1, 3, figsize = (20,20))
img = cv2.imread('C:\\Users\\80SM01YGIH\\Anish\\CV101\\Data\\messi5.jpg')
img_gry = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
ax[0].imshow(img)
ax[0].title.set_text('original_image')
ax[1].imshow(img_gry)
ax[1].title.set_text('img_gray without cmap')
ax[2].imshow(img_gry, cmap = 'gray')
ax[2].title.set_text('img_gray with cmap')
#cv2.waitKey(0)
#cv2.destroyAllWindows()

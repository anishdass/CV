# %%
# !pip install opencv-python
# Out:
# Collecting opencv-python
#   Downloading https://files.pythonhosted.org/packages/b6/ef/ad0423cae9abb45bf536af451f1f65bea35369b56aca36908560efcf6a9f/opencv_python-4.2.0.34-cp36-cp36m-win_amd64.whl (33.0MB)
# Requirement already satisfied: numpy>=1.11.3 in c:\programdata\anaconda3\lib\site-packages (from opencv-python) (1.14.3)
# Installing collected packages: opencv-python
# Successfully installed opencv-python-4.2.0.34
# WARNING: You are using pip version 19.2.3, however version 20.1 is available.
# You should consider upgrading via the 'python -m pip install --upgrade pip' command.

# %%
import numpy as np
import pandas as pd
import cv2
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#img = cv2.imread(cv2.samples.findFile('messi5.jpg'))
img = cv2.imread('C:\\Sample\\Anish.jpg')
plt.imshow(img)v

# %%
fig, axs = plt.subplots(1, 3, figsize = (20, 20))
img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
img_gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
img_hls = cv2.cvtColor(img, cv2.COLOR_BGR2HLS)
img_list = [img_rgb, img_gray, img_hls]

for i in range(0,3):
    ax = axs[i]
    ax.imshow(img_list[i], cmap = 'gray')
